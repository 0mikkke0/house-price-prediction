# %% [markdown]
# # House Price Prediction Analysis\nExploratory analysis for the Ames Housing regression project.

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\ndf = pd.read_csv('../data/ames_housing.csv')\ndf.head()

# %%
df.shape, df['SalePrice'].describe()

# %%
sns.histplot(df['SalePrice'], kde=True)\nplt.title('Sale Price Distribution')\nplt.show()

# %%
numeric = df.select_dtypes(include='number')\ncorr = numeric.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False)\ndisplay(corr.head(12))

# %% [markdown]
# ## Modeling\nThe reproducible preprocessing and model-comparison pipeline is in `src/train.py`.
